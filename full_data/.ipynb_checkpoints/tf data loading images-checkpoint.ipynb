# %%
import tensorflow as tf
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from os import listdir

# %%
from os.path import isfile, join

# %%
mypath = "fifty/"

# %%
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles
# Out:
# ['fifty_train_ - 844.jpg',
#  'fifty_train_ - 850.jpg',
#  'fifty_train_ - 688.jpg',
#  'fifty_train_ - 1383.jpg',
#  'fifty_train_ - 878.jpg',
#  'fifty_train_ - 1397.jpg',
#  'fifty_train_ - 139.jpg',
#  'fifty_train_ - 887.jpg',
#  'fifty_train_ - 893.jpg',
#  'fifty_train_ - 1368.jpg',
#  'fifty_train_ - 1340.jpg',
#  'fifty_train_ - 105.jpg',
#  'fifty_train_ - 663.jpg',
#  'fifty_train_ - 1426.jpg',
#  'fifty_train_ - 677.jpg',
#  'fifty_train_ - 1432.jpg',
#  'fifty_train_ - 1354.jpg',
#  'fifty_train_ - 111.jpg',
#  'fifty_train_ - 1803.jpg',
#  'fifty_train_ - 1817.jpg',
#  'fifty_train_ - 91.jpg',
#  'fifty_train_ - 1181.jpg',
#  'fifty_train_ - 1195.jpg',
#  'fifty_train_ - 85.jpg',
#  'fifty_train_ - 1618.jpg',
#  'fifty_train_ - 449.jpg',
#  'fifty_train_ - 1624.jpg',
#  'fifty_train_ - 461.jpg',
#  'fifty_train_ - 52.jpg',
#  'fifty_train_ - 307.jpg',
#  'fifty_train_ - 1142.jpg',
#  'fifty_train_ - 313.jpg',
#  'fifty_train_ - 1156.jpg',
#  'fifty_train_ - 1630.jpg',
#  'fifty_train_ - 475.jpg',
#  'fifty_train_ - 46.jpg',
#  'fifty_train_ - 1977.jpg',
#  'fifty_train_ - 298.jpg',
#  'fifty_train_ - 1963.jpg',
#  'fifty_train_ - 1793.jpg',
#  'fifty_train_ - 1787.jpg',
#  'fifty_train_ - 529.jpg',
#  'fifty_train_ - 1778.jpg',
#  'fifty_train_ - 1988.jpg',
#  'fifty_train_ - 515.jpg',
#  'fifty_train_ - 1750.jpg',
#  'fifty_train_ - 1036.jpg',
#  'fifty_train_ - 273.jpg',
#  'fifty_train_ - 1022.jpg',
#  'fifty_train_ - 267.jpg',
#  'fifty_train_ - 501.jpg',
#  'fifty_train_ - 1744.jpg',
#  'fifty_train_ - 930.jpg',
#  'fifty_train_ - 924.jpg',
#  'fifty_train_ - 1591.jpg',
#  'fifty_train_ - 918.jpg',
#  'fifty_train_ - 1585.jpg',
#  'fifty_train_ - 1208.jpg',
#  'fifty_train_ - 1234.jpg',
#  'fifty_train_ - 1552.jpg',
#  'fifty_train_ - 717.jpg',
#  'fifty_train_ - 1546.jpg',
#  'fifty_train_ - 703.jpg',
#  'fifty_train_ - 1220.jpg',
#  'fifty_train_ - 702.jpg',
#  'fifty_train_ - 1547.jpg',
#  'fifty_train_ - 1221.jpg',
#  'fifty_train_ - 1235.jpg',
#  'fifty_train_ - 716.jpg',
#  'fifty_train_ - 1553.jpg',
#  'fifty_train_ - 1209.jpg',
#  'fifty_train_ - 1584.jpg',
#  'fifty_train_ - 919.jpg',
#  'fifty_train_ - 1590.jpg',
#  'fifty_train_ - 925.jpg',
#  'fifty_train_ - 931.jpg',
#  'fifty_train_ - 266.jpg',
#  'fifty_train_ - 1023.jpg',
#  'fifty_train_ - 1745.jpg',
#  'fifty_train_ - 500.jpg',
#  'fifty_train_ - 1751.jpg',
#  'fifty_train_ - 514.jpg',
#  'fifty_train_ - 1989.jpg',
#  'fifty_train_ - 272.jpg',
#  'fifty_train_ - 1037.jpg',
#  'fifty_train_ - 1779.jpg',
#  'fifty_train_ - 528.jpg',
#  'fifty_train_ - 1786.jpg',
#  'fifty_train_ - 1792.jpg',
#  'fifty_train_ - 299.jpg',
#  'fifty_train_ - 1962.jpg',
#  'fifty_train_ - 1976.jpg',
#  'fifty_train_ - 1157.jpg',
#  'fifty_train_ - 312.jpg',
#  'fifty_train_ - 47.jpg',
#  'fifty_train_ - 474.jpg',
#  'fifty_train_ - 1631.jpg',
#  'fifty_train_ - 53.jpg',
#  'fifty_train_ - 460.jpg',
#  'fifty_train_ - 1625.jpg',
#  'fifty_train_ - 1143.jpg',
#  'fifty_train_ - 306.jpg',
#  'fifty_train_ - 448.jpg',
#  'fifty_train_ - 1619.jpg',
#  'fifty_train_ - 1194.jpg',
#  'fifty_train_ - 84.jpg',
#  'fifty_train_ - 90.jpg',
#  'fifty_train_ - 1180.jpg',
#  'fifty_train_ - 1816.jpg',
#  'fifty_train_ - 1802.jpg',
#  'fifty_train_ - 1433.jpg',
#  'fifty_train_ - 676.jpg',
#  'fifty_train_ - 110.jpg',
#  'fifty_train_ - 1355.jpg',
#  'fifty_train_ - 104.jpg',
#  'fifty_train_ - 1341.jpg',
#  'fifty_train_ - 1427.jpg',
#  'fifty_train_ - 662.jpg',
#  'fifty_train_ - 892.jpg',
#  'fifty_train_ - 1369.jpg',
#  'fifty_train_ - 138.jpg',
#  'fifty_train_ - 886.jpg',
#  'fifty_train_ - 1396.jpg',
#  'fifty_train_ - 1382.jpg',
#  'fifty_train_ - 879.jpg',
#  'fifty_train_ - 689.jpg',
#  'fifty_train_ - 851.jpg',
#  'fifty_train_ - 845.jpg',
#  'fifty_train_ - 853.jpg',
#  'fifty_train_ - 847.jpg',
#  'fifty_train_ - 1394.jpg',
#  'fifty_train_ - 1380.jpg',
#  'fifty_train_ - 648.jpg',
#  'fifty_train_ - 890.jpg',
#  'fifty_train_ - 1419.jpg',
#  'fifty_train_ - 884.jpg',
#  'fifty_train_ - 1357.jpg',
#  'fifty_train_ - 112.jpg',
#  'fifty_train_ - 674.jpg',
#  'fifty_train_ - 1431.jpg',
#  'fifty_train_ - 660.jpg',
#  'fifty_train_ - 1425.jpg',
#  'fifty_train_ - 1343.jpg',
#  'fifty_train_ - 106.jpg',
#  'fifty_train_ - 489.jpg',
#  'fifty_train_ - 1814.jpg',
#  'fifty_train_ - 1800.jpg',
#  'fifty_train_ - 86.jpg',
#  'fifty_train_ - 1828.jpg',
#  'fifty_train_ - 1196.jpg',
#  'fifty_train_ - 1182.jpg',
#  'fifty_train_ - 92.jpg',
#  'fifty_train_ - 79.jpg',
#  'fifty_train_ - 1169.jpg',
#  'fifty_train_ - 338.jpg',
#  'fifty_train_ - 1633.jpg',
#  'fifty_train_ - 476.jpg',
#  'fifty_train_ - 45.jpg',
#  'fifty_train_ - 310.jpg',
#  'fifty_train_ - 1155.jpg',
#  'fifty_train_ - 304.jpg',
#  'fifty_train_ - 1141.jpg',
#  'fifty_train_ - 1627.jpg',
#  'fifty_train_ - 462.jpg',
#  'fifty_train_ - 51.jpg',
#  'fifty_train_ - 1960.jpg',
#  'fifty_train_ - 1974.jpg',
#  'fifty_train_ - 1784.jpg',
#  'fifty_train_ - 1790.jpg',
#  'fifty_train_ - 1948.jpg',
#  'fifty_train_ - 258.jpg',
#  'fifty_train_ - 1009.jpg',
#  'fifty_train_ - 502.jpg',
#  'fifty_train_ - 1747.jpg',
#  'fifty_train_ - 1021.jpg',
#  'fifty_train_ - 264.jpg',
#  'fifty_train_ - 1035.jpg',
#  'fifty_train_ - 270.jpg',
#  'fifty_train_ - 516.jpg',
#  'fifty_train_ - 1753.jpg',
#  'fifty_train_ - 927.jpg',
#  'fifty_train_ - 933.jpg',
#  'fifty_train_ - 1586.jpg',
#  'fifty_train_ - 1592.jpg',
#  'fifty_train_ - 1579.jpg',
#  'fifty_train_ - 728.jpg',
#  'fifty_train_ - 1223.jpg',
#  'fifty_train_ - 1545.jpg',
#  'fifty_train_ - 700.jpg',
#  'fifty_train_ - 1551.jpg',
#  'fifty_train_ - 714.jpg',
#  'fifty_train_ - 1237.jpg',
#  'fifty_train_ - 715.jpg',
#  'fifty_train_ - 1550.jpg',
#  'fifty_train_ - 1236.jpg',
#  'fifty_train_ - 1222.jpg',
#  'fifty_train_ - 701.jpg',
#  'fifty_train_ - 1544.jpg',
#  'fifty_train_ - 729.jpg',
#  'fifty_train_ - 1578.jpg',
#  'fifty_train_ - 1593.jpg',
#  'fifty_train_ - 1587.jpg',
#  'fifty_train_ - 932.jpg',
#  'fifty_train_ - 926.jpg',
#  'fifty_train_ - 271.jpg',
#  'fifty_train_ - 1034.jpg',
#  'fifty_train_ - 1752.jpg',
#  'fifty_train_ - 517.jpg',
#  'fifty_train_ - 1746.jpg',
#  'fifty_train_ - 503.jpg',
#  'fifty_train_ - 265.jpg',
#  'fifty_train_ - 1020.jpg',
#  'fifty_train_ - 1008.jpg',
#  'fifty_train_ - 259.jpg',
#  'fifty_train_ - 1949.jpg',
#  'fifty_train_ - 1791.jpg',
#  'fifty_train_ - 1785.jpg',
#  'fifty_train_ - 1975.jpg',
#  'fifty_train_ - 1961.jpg',
#  'fifty_train_ - 1140.jpg',
#  'fifty_train_ - 305.jpg',
#  'fifty_train_ - 50.jpg',
#  'fifty_train_ - 463.jpg',
#  'fifty_train_ - 1626.jpg',
#  'fifty_train_ - 44.jpg',
#  'fifty_train_ - 477.jpg',
#  'fifty_train_ - 1632.jpg',
#  'fifty_train_ - 1154.jpg',
#  'fifty_train_ - 311.jpg',
#  'fifty_train_ - 339.jpg',
#  'fifty_train_ - 78.jpg',
#  'fifty_train_ - 1168.jpg',
#  'fifty_train_ - 1183.jpg',
#  'fifty_train_ - 93.jpg',
#  'fifty_train_ - 1829.jpg',
#  'fifty_train_ - 87.jpg',
#  'fifty_train_ - 1197.jpg',
#  'fifty_train_ - 1801.jpg',
#  'fifty_train_ - 1815.jpg',
#  'fifty_train_ - 488.jpg',
#  'fifty_train_ - 1424.jpg',
#  'fifty_train_ - 661.jpg',
#  'fifty_train_ - 107.jpg',
#  'fifty_train_ - 1342.jpg',
#  'fifty_train_ - 113.jpg',
#  'fifty_train_ - 1356.jpg',
#  'fifty_train_ - 1430.jpg',
#  'fifty_train_ - 675.jpg',
#  'fifty_train_ - 885.jpg',
#  'fifty_train_ - 1418.jpg',
#  'fifty_train_ - 891.jpg',
#  'fifty_train_ - 649.jpg',
#  'fifty_train_ - 1381.jpg',
#  'fifty_train_ - 1395.jpg',
#  'fifty_train_ - 846.jpg',
#  'fifty_train_ - 852.jpg',
#  'fifty_train_ - 1391.jpg',
#  'fifty_train_ - 1385.jpg',
#  'fifty_train_ - 856.jpg',
#  'fifty_train_ - 842.jpg',
#  'fifty_train_ - 671.jpg',
#  'fifty_train_ - 1434.jpg',
#  'fifty_train_ - 1352.jpg',
#  'fifty_train_ - 117.jpg',
#  'fifty_train_ - 1346.jpg',
#  'fifty_train_ - 103.jpg',
#  'fifty_train_ - 665.jpg',
#  'fifty_train_ - 1420.jpg',
#  'fifty_train_ - 895.jpg',
#  'fifty_train_ - 1408.jpg',
#  'fifty_train_ - 659.jpg',
#  'fifty_train_ - 881.jpg',
#  'fifty_train_ - 1193.jpg',
#  'fifty_train_ - 83.jpg',
#  'fifty_train_ - 97.jpg',
#  'fifty_train_ - 1839.jpg',
#  'fifty_train_ - 1187.jpg',
#  'fifty_train_ - 1811.jpg',
#  'fifty_train_ - 1805.jpg',
#  'fifty_train_ - 498.jpg',
#  'fifty_train_ - 315.jpg',
#  'fifty_train_ - 1150.jpg',
#  'fifty_train_ - 1636.jpg',
#  'fifty_train_ - 40.jpg',
#  'fifty_train_ - 473.jpg',
#  'fifty_train_ - 1622.jpg',
#  'fifty_train_ - 54.jpg',
#  'fifty_train_ - 467.jpg',
#  'fifty_train_ - 301.jpg',
#  'fifty_train_ - 1144.jpg',
#  'fifty_train_ - 329.jpg',
#  'fifty_train_ - 68.jpg',
#  'fifty_train_ - 1178.jpg',
#  'fifty_train_ - 1781.jpg',
#  'fifty_train_ - 1959.jpg',
#  'fifty_train_ - 1795.jpg',
#  'fifty_train_ - 1965.jpg',
#  'fifty_train_ - 1971.jpg',
#  'fifty_train_ - 1024.jpg',
#  'fifty_train_ - 261.jpg',
#  'fifty_train_ - 507.jpg',
#  'fifty_train_ - 1742.jpg',
#  'fifty_train_ - 513.jpg',
#  'fifty_train_ - 1756.jpg',
#  'fifty_train_ - 1030.jpg',
#  'fifty_train_ - 275.jpg',
#  'fifty_train_ - 1018.jpg',
#  'fifty_train_ - 249.jpg',
#  'fifty_train_ - 1583.jpg',
#  'fifty_train_ - 1597.jpg',
#  'fifty_train_ - 922.jpg',
#  'fifty_train_ - 936.jpg',
#  'fifty_train_ - 1540.jpg',
#  'fifty_train_ - 705.jpg',
#  'fifty_train_ - 1226.jpg',
#  'fifty_train_ - 1232.jpg',
#  'fifty_train_ - 1554.jpg',
#  'fifty_train_ - 711.jpg',
#  'fifty_train_ - 739.jpg',
#  'fifty_train_ - 1568.jpg',
#  'fifty_train_ - 1569.jpg',
#  'fifty_train_ - 738.jpg',
#  'fifty_train_ - 1233.jpg',
#  'fifty_train_ - 710.jpg',
#  'fifty_train_ - 1555.jpg',
#  'fifty_train_ - 704.jpg',
#  'fifty_train_ - 1541.jpg',
#  'fifty_train_ - 1227.jpg',
#  'fifty_train_ - 937.jpg',
#  'fifty_train_ - 923.jpg',
#  'fifty_train_ - 1596.jpg',
#  'fifty_train_ - 1582.jpg',
#  'fifty_train_ - 248.jpg',
#  'fifty_train_ - 1019.jpg',
#  'fifty_train_ - 1757.jpg',
#  'fifty_train_ - 512.jpg',
#  'fifty_train_ - 274.jpg',
#  'fifty_train_ - 1031.jpg',
#  'fifty_train_ - 260.jpg',
#  'fifty_train_ - 1025.jpg',
#  'fifty_train_ - 1743.jpg',
#  'fifty_train_ - 506.jpg',
#  'fifty_train_ - 1970.jpg',
#  'fifty_train_ - 1964.jpg',
#  'fifty_train_ - 1794.jpg',
#  'fifty_train_ - 1958.jpg',
#  'fifty_train_ - 1780.jpg',
#  'fifty_train_ - 69.jpg',
#  'fifty_train_ - 1179.jpg',
#  'fifty_train_ - 328.jpg',
#  'fifty_train_ - 466.jpg',
#  'fifty_train_ - 55.jpg',
#  'fifty_train_ - 1623.jpg',
#  'fifty_train_ - 1145.jpg',
#  'fifty_train_ - 300.jpg',
#  'fifty_train_ - 1151.jpg',
#  'fifty_train_ - 314.jpg',
#  'fifty_train_ - 472.jpg',
#  'fifty_train_ - 41.jpg',
#  'fifty_train_ - 1637.jpg',
#  'fifty_train_ - 499.jpg',
#  'fifty_train_ - 1804.jpg',
#  'fifty_train_ - 1810.jpg',
#  'fifty_train_ - 1838.jpg',
#  'fifty_train_ - 96.jpg',
#  'fifty_train_ - 1186.jpg',
#  'fifty_train_ - 1192.jpg',
#  'fifty_train_ - 82.jpg',
#  'fifty_train_ - 880.jpg',
#  'fifty_train_ - 658.jpg',
#  'fifty_train_ - 1409.jpg',
#  'fifty_train_ - 894.jpg',
#  'fifty_train_ - 102.jpg',
#  'fifty_train_ - 1347.jpg',
#  'fifty_train_ - 1421.jpg',
#  'fifty_train_ - 664.jpg',
#  'fifty_train_ - 1435.jpg',
#  'fifty_train_ - 670.jpg',
#  'fifty_train_ - 116.jpg',
#  'fifty_train_ - 1353.jpg',
#  'fifty_train_ - 843.jpg',
#  'fifty_train_ - 857.jpg',
#  'fifty_train_ - 1384.jpg',
#  'fifty_train_ - 1390.jpg',
#  'fifty_train_ - 1386.jpg',
#  'fifty_train_ - 1392.jpg',
#  'fifty_train_ - 869.jpg',
#  'fifty_train_ - 841.jpg',
#  'fifty_train_ - 699.jpg',
#  'fifty_train_ - 855.jpg',
#  'fifty_train_ - 666.jpg',
#  'fifty_train_ - 1423.jpg',
#  'fifty_train_ - 1345.jpg',
#  'fifty_train_ - 100.jpg',
#  'fifty_train_ - 1351.jpg',
#  'fifty_train_ - 114.jpg',
#  'fifty_train_ - 672.jpg',
#  'fifty_train_ - 1437.jpg',
#  'fifty_train_ - 882.jpg',
#  'fifty_train_ - 1379.jpg',
#  'fifty_train_ - 128.jpg',
#  'fifty_train_ - 896.jpg',
#  'fifty_train_ - 1184.jpg',
#  'fifty_train_ - 94.jpg',
#  'fifty_train_ - 80.jpg',
#  'fifty_train_ - 1190.jpg',
#  'fifty_train_ - 1806.jpg',
#  'fifty_train_ - 1812.jpg',
#  'fifty_train_ - 302.jpg',
#  'fifty_train_ - 1147.jpg',
#  'fifty_train_ - 1621.jpg',
#  'fifty_train_ - 57.jpg',
#  'fifty_train_ - 464.jpg',
#  'fifty_train_ - 1635.jpg',
#  'fifty_train_ - 43.jpg',
#  'fifty_train_ - 470.jpg',
#  'fifty_train_ - 316.jpg',
#  'fifty_train_ - 1153.jpg',
#  'fifty_train_ - 458.jpg',
#  'fifty_train_ - 1609.jpg',
#  'fifty_train_ - 1796.jpg',
#  'fifty_train_ - 1782.jpg',
#  'fifty_train_ - 289.jpg',
#  'fifty_train_ - 1972.jpg',
#  'fifty_train_ - 1966.jpg',
#  'fifty_train_ - 1033.jpg',
#  'fifty_train_ - 276.jpg',
#  'fifty_train_ - 510.jpg',
#  'fifty_train_ - 1755.jpg',
#  'fifty_train_ - 504.jpg',
#  'fifty_train_ - 1999.jpg',
#  'fifty_train_ - 1741.jpg',
#  'fifty_train_ - 1027.jpg',
#  'fifty_train_ - 262.jpg',
#  'fifty_train_ - 1769.jpg',
#  'fifty_train_ - 538.jpg',
#  'fifty_train_ - 1594.jpg',
#  'fifty_train_ - 909.jpg',
#  'fifty_train_ - 1580.jpg',
#  'fifty_train_ - 935.jpg',
#  'fifty_train_ - 921.jpg',
#  'fifty_train_ - 1557.jpg',
#  'fifty_train_ - 712.jpg',
#  'fifty_train_ - 1231.jpg',
#  'fifty_train_ - 1225.jpg',
#  'fifty_train_ - 1543.jpg',
#  'fifty_train_ - 706.jpg',
#  'fifty_train_ - 1219.jpg',
#  'fifty_train_ - 1218.jpg',
#  'fifty_train_ - 1224.jpg',
#  'fifty_train_ - 707.jpg',
#  'fifty_train_ - 1542.jpg',
#  'fifty_train_ - 713.jpg',
#  'fifty_train_ - 1556.jpg',
#  'fifty_train_ - 1230.jpg',
#  'fifty_train_ - 920.jpg',
#  'fifty_train_ - 934.jpg',
#  'fifty_train_ - 1581.jpg',
#  'fifty_train_ - 908.jpg',
#  'fifty_train_ - 1595.jpg',
#  'fifty_train_ - 539.jpg',
#  'fifty_train_ - 1768.jpg',
#  'fifty_train_ - 1740.jpg',
#  'fifty_train_ - 1998.jpg',
#  'fifty_train_ - 505.jpg',
#  'fifty_train_ - 263.jpg',
#  'fifty_train_ - 1026.jpg',
#  'fifty_train_ - 277.jpg',
#  'fifty_train_ - 1032.jpg',
#  'fifty_train_ - 1754.jpg',
#  'fifty_train_ - 511.jpg',
#  'fifty_train_ - 1967.jpg',
#  'fifty_train_ - 288.jpg',
#  'fifty_train_ - 1973.jpg',
#  'fifty_train_ - 1783.jpg',
#  'fifty_train_ - 1797.jpg',
#  'fifty_train_ - 1608.jpg',
#  'fifty_train_ - 459.jpg',
#  'fifty_train_ - 471.jpg',
#  'fifty_train_ - 42.jpg',
#  'fifty_train_ - 1634.jpg',
#  'fifty_train_ - 1152.jpg',
#  'fifty_train_ - 317.jpg',
#  'fifty_train_ - 1146.jpg',
#  'fifty_train_ - 303.jpg',
#  'fifty_train_ - 465.jpg',
#  'fifty_train_ - 56.jpg',
#  'fifty_train_ - 1620.jpg',
#  'fifty_train_ - 1813.jpg',
#  'fifty_train_ - 1807.jpg',
#  'fifty_train_ - 81.jpg',
#  'fifty_train_ - 1191.jpg',
#  'fifty_train_ - 1185.jpg',
#  'fifty_train_ - 95.jpg',
#  'fifty_train_ - 129.jpg',
#  'fifty_train_ - 897.jpg',
#  'fifty_train_ - 883.jpg',
#  'fifty_train_ - 1378.jpg',
#  'fifty_train_ - 115.jpg',
#  'fifty_train_ - 1350.jpg',
#  'fifty_train_ - 1436.jpg',
#  'fifty_train_ - 673.jpg',
#  'fifty_train_ - 1422.jpg',
#  'fifty_train_ - 667.jpg',
#  'fifty_train_ - 101.jpg',
#  'fifty_train_ - 1344.jpg',
#  'fifty_train_ - 854.jpg',
#  'fifty_train_ - 698.jpg',
#  'fifty_train_ - 840.jpg',
#  'fifty_train_ - 1393.jpg',
#  'fifty_train_ - 868.jpg',
#  'fifty_train_ - 1387.jpg',
#  'fifty_train_ - 827.jpg',
#  'fifty_train_ - 199.jpg',
#  'fifty_train_ - 833.jpg',
#  'fifty_train_ - 1486.jpg',
#  'fifty_train_ - 1492.jpg',
#  'fifty_train_ - 1479.jpg',
#  'fifty_train_ - 628.jpg',
#  'fifty_train_ - 600.jpg',
#  'fifty_train_ - 1445.jpg',
#  'fifty_train_ - 1323.jpg',
#  'fifty_train_ - 166.jpg',
#  'fifty_train_ - 1337.jpg',
#  'fifty_train_ - 172.jpg',
#  'fifty_train_ - 614.jpg',
#  'fifty_train_ - 1451.jpg',
#  'fifty_train_ - 1860.jpg',
#  'fifty_train_ - 1874.jpg',
#  'fifty_train_ - 1684.jpg',
#  'fifty_train_ - 1848.jpg',
#  'fifty_train_ - 1690.jpg',
#  'fifty_train_ - 358.jpg',
#  'fifty_train_ - 19.jpg',
#  'fifty_train_ - 1109.jpg',
#  'fifty_train_ - 364.jpg',
#  'fifty_train_ - 1121.jpg',
#  'fifty_train_ - 1647.jpg',
#  'fifty_train_ - 402.jpg',
#  'fifty_train_ - 31.jpg',
#  'fifty_train_ - 1653.jpg',
#  'fifty_train_ - 416.jpg',
#  'fifty_train_ - 25.jpg',
#  'fifty_train_ - 370.jpg',
#  'fifty_train_ - 1135.jpg',
#  'fifty_train_ - 1914.jpg',
#  'fifty_train_ - 589.jpg',
#  'fifty_train_ - 1900.jpg',
#  'fifty_train_ - 1096.jpg',
#  'fifty_train_ - 1928.jpg',
#  'fifty_train_ - 1082.jpg',
#  'fifty_train_ - 1069.jpg',
#  'fifty_train_ - 238.jpg',
#  'fifty_train_ - 1055.jpg',
#  'fifty_train_ - 210.jpg',
#  'fifty_train_ - 576.jpg',
#  'fifty_train_ - 1733.jpg',
#  'fifty_train_ - 562.jpg',
#  'fifty_train_ - 1727.jpg',
#  'fifty_train_ - 1041.jpg',
#  'fifty_train_ - 204.jpg',
#  'fifty_train_ - 953.jpg',
#  'fifty_train_ - 947.jpg',
#  'fifty_train_ - 1294.jpg',
#  'fifty_train_ - 1280.jpg',
#  'fifty_train_ - 7.jpg',
#  'fifty_train_ - 990.jpg',
#  'fifty_train_ - 748.jpg',
#  'fifty_train_ - 2004.jpg',
#  'fifty_train_ - 2010.jpg',
#  'fifty_train_ - 984.jpg',
#  'fifty_train_ - 1519.jpg',
#  'fifty_train_ - 1531.jpg',
#  'fifty_train_ - 774.jpg',
#  'fifty_train_ - 1257.jpg',
#  'fifty_train_ - 1243.jpg',
#  'fifty_train_ - 1525.jpg',
#  'fifty_train_ - 760.jpg',
#  'fifty_train_ - 1242.jpg',
#  'fifty_train_ - 761.jpg',
#  'fifty_train_ - 1524.jpg',
#  'fifty_train_ - 775.jpg',
#  'fifty_train_ - 1530.jpg',
#  'fifty_train_ - 1256.jpg',
#  'fifty_train_ - 1518.jpg',
#  'fifty_train_ - 985.jpg',
#  'fifty_train_ - 2011.jpg',
#  'fifty_train_ - 2005.jpg',
#  'fifty_train_ - 749.jpg',
#  'fifty_train_ - 991.jpg',
#  'fifty_train_ - 6.jpg',
#  'fifty_train_ - 1281.jpg',
#  'fifty_train_ - 1295.jpg',
#  'fifty_train_ - 946.jpg',
#  'fifty_train_ - 952.jpg',
#  'fifty_train_ - 1726.jpg',
#  'fifty_train_ - 563.jpg',
#  'fifty_train_ - 205.jpg',
#  'fifty_train_ - 1040.jpg',
#  'fifty_train_ - 211.jpg',
#  'fifty_train_ - 1054.jpg',
#  'fifty_train_ - 1732.jpg',
#  'fifty_train_ - 577.jpg',
#  'fifty_train_ - 239.jpg',
#  'fifty_train_ - 1068.jpg',
#  'fifty_train_ - 1083.jpg',
#  'fifty_train_ - 1097.jpg',
#  'fifty_train_ - 1929.jpg',
#  'fifty_train_ - 1901.jpg',
#  'fifty_train_ - 588.jpg',
#  'fifty_train_ - 1915.jpg',
#  'fifty_train_ - 24.jpg',
#  'fifty_train_ - 417.jpg',
#  'fifty_train_ - 1652.jpg',
#  'fifty_train_ - 1134.jpg',
#  'fifty_train_ - 371.jpg',
#  'fifty_train_ - 1120.jpg',
#  'fifty_train_ - 365.jpg',
#  'fifty_train_ - 30.jpg',
#  'fifty_train_ - 403.jpg',
#  'fifty_train_ - 1646.jpg',
#  'fifty_train_ - 18.jpg',
#  'fifty_train_ - 1108.jpg',
#  'fifty_train_ - 359.jpg',
#  'fifty_train_ - 1691.jpg',
#  'fifty_train_ - 1849.jpg',
#  'fifty_train_ - 1685.jpg',
#  'fifty_train_ - 1875.jpg',
#  'fifty_train_ - 1861.jpg',
#  'fifty_train_ - 173.jpg',
#  'fifty_train_ - 1336.jpg',
#  'fifty_train_ - 1450.jpg',
#  'fifty_train_ - 615.jpg',
#  'fifty_train_ - 1444.jpg',
#  'fifty_train_ - 601.jpg',
#  'fifty_train_ - 167.jpg',
#  'fifty_train_ - 1322.jpg',
#  'fifty_train_ - 629.jpg',
#  'fifty_train_ - 1478.jpg',
#  'fifty_train_ - 1493.jpg',
#  'fifty_train_ - 1487.jpg',
#  'fifty_train_ - 832.jpg',
#  'fifty_train_ - 826.jpg',
#  'fifty_train_ - 198.jpg',
#  'fifty_train_ - 830.jpg',
#  'fifty_train_ - 824.jpg',
#  'fifty_train_ - 1491.jpg',
#  'fifty_train_ - 1485.jpg',
#  'fifty_train_ - 818.jpg',
#  'fifty_train_ - 1308.jpg',
#  'fifty_train_ - 159.jpg',
#  'fifty_train_ - 617.jpg',
#  'fifty_train_ - 1452.jpg',
#  'fifty_train_ - 1334.jpg',
#  'fifty_train_ - 171.jpg',
#  'fifty_train_ - 1320.jpg',
#  'fifty_train_ - 165.jpg',
#  'fifty_train_ - 603.jpg',
#  'fifty_train_ - 1446.jpg',
#  'fifty_train_ - 1877.jpg',
#  'fifty_train_ - 1863.jpg',
#  'fifty_train_ - 398.jpg',
#  'fifty_train_ - 1693.jpg',
#  'fifty_train_ - 1687.jpg',
#  'fifty_train_ - 429.jpg',
#  'fifty_train_ - 1678.jpg',
#  'fifty_train_ - 373.jpg',
#  'fifty_train_ - 1136.jpg',
#  'fifty_train_ - 1650.jpg',
#  'fifty_train_ - 415.jpg',
#  'fifty_train_ - 1888.jpg',
#  'fifty_train_ - 26.jpg',
#  'fifty_train_ - 1644.jpg',
#  'fifty_train_ - 401.jpg',
#  'fifty_train_ - 32.jpg',
#  'fifty_train_ - 367.jpg',
#  'fifty_train_ - 1122.jpg',
#  'fifty_train_ - 1903.jpg',
#  'fifty_train_ - 1917.jpg',
#  'fifty_train_ - 1081.jpg',
#  'fifty_train_ - 1095.jpg',
#  'fifty_train_ - 1718.jpg',
#  'fifty_train_ - 549.jpg',
#  'fifty_train_ - 1042.jpg',
#  'fifty_train_ - 207.jpg',
#  'fifty_train_ - 561.jpg',
#  'fifty_train_ - 1724.jpg',
#  'fifty_train_ - 575.jpg',
#  'fifty_train_ - 1730.jpg',
#  'fifty_train_ - 1056.jpg',
#  'fifty_train_ - 213.jpg',
#  'fifty_train_ - 944.jpg',
#  'fifty_train_ - 788.jpg',
#  'fifty_train_ - 950.jpg',
#  'fifty_train_ - 978.jpg',
#  'fifty_train_ - 1283.jpg',
#  'fifty_train_ - 4.jpg',
#  'fifty_train_ - 1297.jpg',
#  'fifty_train_ - 2013.jpg',
#  'fifty_train_ - 987.jpg',
#  'fifty_train_ - 1268.jpg',
#  'fifty_train_ - 993.jpg',
#  'fifty_train_ - 2007.jpg',
#  'fifty_train_ - 1526.jpg',
#  'fifty_train_ - 763.jpg',
#  'fifty_train_ - 1240.jpg',
#  'fifty_train_ - 1254.jpg',
#  'fifty_train_ - 1532.jpg',
#  'fifty_train_ - 777.jpg',
#  'fifty_train_ - 1255.jpg',
#  'fifty_train_ - 776.jpg',
#  'fifty_train_ - 1533.jpg',
#  'fifty_train_ - 762.jpg',
#  'fifty_train_ - 1527.jpg',
#  'fifty_train_ - 1241.jpg',
#  'fifty_train_ - 1269.jpg',
#  'fifty_train_ - 2006.jpg',
#  'fifty_train_ - 992.jpg',
#  'fifty_train_ - 986.jpg',
#  'fifty_train_ - 2012.jpg',
#  'fifty_train_ - 1296.jpg',
#  'fifty_train_ - 979.jpg',
#  'fifty_train_ - 5.jpg',
#  'fifty_train_ - 1282.jpg',
#  'fifty_train_ - 951.jpg',
#  'fifty_train_ - 789.jpg',
#  'fifty_train_ - 945.jpg',
#  'fifty_train_ - 1731.jpg',
#  'fifty_train_ - 574.jpg',
#  'fifty_train_ - 212.jpg',
#  'fifty_train_ - 1057.jpg',
#  'fifty_train_ - 206.jpg',
#  'fifty_train_ - 1043.jpg',
#  'fifty_train_ - 1725.jpg',
#  'fifty_train_ - 560.jpg',
#  'fifty_train_ - 548.jpg',
#  'fifty_train_ - 1719.jpg',
#  'fifty_train_ - 1094.jpg',
#  'fifty_train_ - 1080.jpg',
#  'fifty_train_ - 1916.jpg',
#  'fifty_train_ - 1902.jpg',
#  'fifty_train_ - 33.jpg',
#  'fifty_train_ - 400.jpg',
#  'fifty_train_ - 1645.jpg',
#  'fifty_train_ - 1123.jpg',
#  'fifty_train_ - 366.jpg',
#  'fifty_train_ - 1137.jpg',
#  'fifty_train_ - 372.jpg',
#  'fifty_train_ - 27.jpg',
#  'fifty_train_ - 1889.jpg',
#  'fifty_train_ - 414.jpg',
#  'fifty_train_ - 1651.jpg',
#  'fifty_train_ - 1679.jpg',
#  'fifty_train_ - 428.jpg',
#  'fifty_train_ - 1686.jpg',
#  'fifty_train_ - 1692.jpg',
#  'fifty_train_ - 1862.jpg',
#  'fifty_train_ - 399.jpg',
#  'fifty_train_ - 1876.jpg',
#  'fifty_train_ - 164.jpg',
#  'fifty_train_ - 1321.jpg',
#  'fifty_train_ - 1447.jpg',
#  'fifty_train_ - 602.jpg',
#  'fifty_train_ - 1453.jpg',
#  'fifty_train_ - 616.jpg',
#  'fifty_train_ - 170.jpg',
#  'fifty_train_ - 1335.jpg',
#  'fifty_train_ - 158.jpg',
#  'fifty_train_ - 1309.jpg',
#  'fifty_train_ - 819.jpg',
#  'fifty_train_ - 1484.jpg',
#  'fifty_train_ - 1490.jpg',
#  'fifty_train_ - 825.jpg',
#  'fifty_train_ - 831.jpg',
#  'fifty_train_ - 809.jpg',
#  'fifty_train_ - 1494.jpg',
#  'fifty_train_ - 1480.jpg',
#  'fifty_train_ - 835.jpg',
#  'fifty_train_ - 821.jpg',
#  'fifty_train_ - 1331.jpg',
#  'fifty_train_ - 174.jpg',
#  'fifty_train_ - 612.jpg',
#  'fifty_train_ - 1457.jpg',
#  'fifty_train_ - 606.jpg',
#  'fifty_train_ - 1443.jpg',
#  'fifty_train_ - 1325.jpg',
#  'fifty_train_ - 160.jpg',
#  'fifty_train_ - 148.jpg',
#  'fifty_train_ - 1319.jpg',
#  'fifty_train_ - 1696.jpg',
#  'fifty_train_ - 1682.jpg',
#  'fifty_train_ - 1872.jpg',
#  'fifty_train_ - 389.jpg',
#  'fifty_train_ - 1866.jpg',
#  'fifty_train_ - 1655.jpg',
#  'fifty_train_ - 23.jpg',
#  'fifty_train_ - 410.jpg',
#  'fifty_train_ - 376.jpg',
#  'fifty_train_ - 1133.jpg',
#  'fifty_train_ - 362.jpg',
#  'fifty_train_ - 1127.jpg',
#  'fifty_train_ - 1641.jpg',
#  'fifty_train_ - 1899.jpg',
#  'fifty_train_ - 37.jpg',
#  'fifty_train_ - 404.jpg',
#  'fifty_train_ - 1669.jpg',
#  'fifty_train_ - 438.jpg',
#  'fifty_train_ - 1084.jpg',
#  'fifty_train_ - 1090.jpg',
#  'fifty_train_ - 1906.jpg',
#  'fifty_train_ - 1912.jpg',
#  'fifty_train_ - 564.jpg',
#  'fifty_train_ - 1721.jpg',
#  'fifty_train_ - 1047.jpg',
#  'fifty_train_ - 202.jpg',
#  'fifty_train_ - 1053.jpg',
#  'fifty_train_ - 216.jpg',
#  'fifty_train_ - 570.jpg',
#  'fifty_train_ - 1735.jpg',
#  'fifty_train_ - 558.jpg',
#  'fifty_train_ - 1709.jpg',
#  'fifty_train_ - 1286.jpg',
#  'fifty_train_ - 1.jpg',
#  'fifty_train_ - 969.jpg',
#  'fifty_train_ - 1292.jpg',
#  'fifty_train_ - 799.jpg',
#  'fifty_train_ - 941.jpg',
#  'fifty_train_ - 955.jpg',
#  'fifty_train_ - 1245.jpg',
#  'fifty_train_ - 1523.jpg',
#  'fifty_train_ - 766.jpg',
#  'fifty_train_ - 1537.jpg',
#  'fifty_train_ - 772.jpg',
#  'fifty_train_ - 1251.jpg',
#  'fifty_train_ - 1279.jpg',
#  'fifty_train_ - 982.jpg',
#  'fifty_train_ - 996.jpg',
#  'fifty_train_ - 2002.jpg',
#  'fifty_train_ - 2003.jpg',
#  'fifty_train_ - 997.jpg',
#  'fifty_train_ - 1278.jpg',
#  'fifty_train_ - 983.jpg',
#  'fifty_train_ - 773.jpg',
#  'fifty_train_ - 1536.jpg',
#  'fifty_train_ - 1250.jpg',
#  'fifty_train_ - 1244.jpg',
#  'fifty_train_ - 767.jpg',
#  'fifty_train_ - 1522.jpg',
#  'fifty_train_ - 954.jpg',
#  'fifty_train_ - 940.jpg',
#  'fifty_train_ - 798.jpg',
#  'fifty_train_ - 968.jpg',
#  'fifty_train_ - 1293.jpg',
#  'fifty_train_ - 1287.jpg',
#  'fifty_train_ - 1708.jpg',
#  'fifty_train_ - 559.jpg',
#  'fifty_train_ - 217.jpg',
#  'fifty_train_ - 1052.jpg',
#  'fifty_train_ - 1734.jpg',
#  'fifty_train_ - 571.jpg',
#  'fifty_train_ - 1720.jpg',
#  'fifty_train_ - 565.jpg',
#  'fifty_train_ - 203.jpg',
#  'fifty_train_ - 1046.jpg',
#  'fifty_train_ - 1913.jpg',
#  'fifty_train_ - 1907.jpg',
#  'fifty_train_ - 1091.jpg',
#  'fifty_train_ - 1085.jpg',
#  'fifty_train_ - 439.jpg',
#  'fifty_train_ - 1668.jpg',
#  'fifty_train_ - 1126.jpg',
#  'fifty_train_ - 363.jpg',
#  'fifty_train_ - 405.jpg',
#  'fifty_train_ - 36.jpg',
#  'fifty_train_ - 1898.jpg',
#  'fifty_train_ - 1640.jpg',
#  'fifty_train_ - 411.jpg',
#  'fifty_train_ - 22.jpg',
#  'fifty_train_ - 1654.jpg',
#  'fifty_train_ - 1132.jpg',
#  'fifty_train_ - 377.jpg',
#  'fifty_train_ - 1867.jpg',
#  'fifty_train_ - 1873.jpg',
#  'fifty_train_ - 388.jpg',
#  'fifty_train_ - 1683.jpg',
#  'fifty_train_ - 1697.jpg',
#  'fifty_train_ - 1318.jpg',
#  'fifty_train_ - 149.jpg',
#  'fifty_train_ - 1442.jpg',
#  'fifty_train_ - 607.jpg',
#  'fifty_train_ - 161.jpg',
#  'fifty_train_ - 1324.jpg',
#  'fifty_train_ - 175.jpg',
#  'fifty_train_ - 1330.jpg',
#  'fifty_train_ - 1456.jpg',
#  'fifty_train_ - 613.jpg',
#  'fifty_train_ - 820.jpg',
#  'fifty_train_ - 834.jpg',
#  'fifty_train_ - 1481.jpg',
#  'fifty_train_ - 1495.jpg',
#  'fifty_train_ - 808.jpg',
#  'fifty_train_ - 1483.jpg',
#  'fifty_train_ - 1497.jpg',
#  'fifty_train_ - 822.jpg',
#  'fifty_train_ - 836.jpg',
#  'fifty_train_ - 188.jpg',
#  'fifty_train_ - 1326.jpg',
#  'fifty_train_ - 163.jpg',
#  'fifty_train_ - 605.jpg',
#  'fifty_train_ - 1440.jpg',
#  'fifty_train_ - 611.jpg',
#  'fifty_train_ - 1454.jpg',
#  'fifty_train_ - 1332.jpg',
#  'fifty_train_ - 177.jpg',
#  'fifty_train_ - 639.jpg',
#  'fifty_train_ - 1468.jpg',
#  'fifty_train_ - 1859.jpg',
#  'fifty_train_ - 1681.jpg',
#  'fifty_train_ - 1695.jpg',
#  'fifty_train_ - 1865.jpg',
#  'fifty_train_ - 1871.jpg',
#  'fifty_train_ - 1642.jpg',
#  'fifty_train_ - 34.jpg',
#  'fifty_train_ - 407.jpg',
#  'fifty_train_ - 361.jpg',
#  'fifty_train_ - 1124.jpg',
#  'fifty_train_ - 375.jpg',
#  'fifty_train_ - 1130.jpg',
#  'fifty_train_ - 1656.jpg',
#  'fifty_train_ - 20.jpg',
#  'fifty_train_ - 413.jpg',
#  'fifty_train_ - 1118.jpg',
#  'fifty_train_ - 349.jpg',
#  'fifty_train_ - 1093.jpg',
#  'fifty_train_ - 1087.jpg',
#  'fifty_train_ - 1939.jpg',
#  'fifty_train_ - 1911.jpg',
#  'fifty_train_ - 598.jpg',
#  'fifty_train_ - 1905.jpg',
#  'fifty_train_ - 573.jpg',
#  'fifty_train_ - 1736.jpg',
#  'fifty_train_ - 1050.jpg',
#  'fifty_train_ - 215.jpg',
#  'fifty_train_ - 1044.jpg',
#  'fifty_train_ - 201.jpg',
#  'fifty_train_ - 567.jpg',
#  'fifty_train_ - 1722.jpg',
#  'fifty_train_ - 229.jpg',
#  'fifty_train_ - 1078.jpg',
#  'fifty_train_ - 1291.jpg',
#  'fifty_train_ - 1285.jpg',
#  'fifty_train_ - 2.jpg',
#  'fifty_train_ - 956.jpg',
#  'fifty_train_ - 942.jpg',
#  'fifty_train_ - 1252.jpg',
#  'fifty_train_ - 1534.jpg',
#  'fifty_train_ - 771.jpg',
#  'fifty_train_ - 1520.jpg',
#  'fifty_train_ - 765.jpg',
#  'fifty_train_ - 1246.jpg',
#  'fifty_train_ - 1508.jpg',
#  'fifty_train_ - 995.jpg',
#  'fifty_train_ - 2001.jpg',
#  'fifty_train_ - 981.jpg',
#  'fifty_train_ - 759.jpg',
#  'fifty_train_ - 758.jpg',
#  'fifty_train_ - 980.jpg',
#  'fifty_train_ - 2014.jpg',
#  'fifty_train_ - 2000.jpg',
#  'fifty_train_ - 994.jpg',
#  'fifty_train_ - 1509.jpg',
#  'fifty_train_ - 764.jpg',
#  'fifty_train_ - 1521.jpg',
#  'fifty_train_ - 1247.jpg',
#  'fifty_train_ - 1253.jpg',
#  'fifty_train_ - 770.jpg',
#  'fifty_train_ - 1535.jpg',
#  'fifty_train_ - 943.jpg',
#  'fifty_train_ - 957.jpg',
#  'fifty_train_ - 3.jpg',
#  'fifty_train_ - 1284.jpg',
#  'fifty_train_ - 1290.jpg',
#  'fifty_train_ - 1079.jpg',
#  'fifty_train_ - 228.jpg',
#  'fifty_train_ - 200.jpg',
#  'fifty_train_ - 1045.jpg',
#  'fifty_train_ - 1723.jpg',
#  'fifty_train_ - 566.jpg',
#  'fifty_train_ - 1737.jpg',
#  'fifty_train_ - 572.jpg',
#  'fifty_train_ - 214.jpg',
#  'fifty_train_ - 1051.jpg',
#  'fifty_train_ - 1904.jpg',
#  'fifty_train_ - 599.jpg',
#  'fifty_train_ - 1910.jpg',
#  'fifty_train_ - 1086.jpg',
#  'fifty_train_ - 1938.jpg',
#  'fifty_train_ - 1092.jpg',
#  'fifty_train_ - 348.jpg',
#  'fifty_train_ - 1119.jpg',
#  ...]

# %%
len(onlyfiles)
# Out:
# 2014

# %%
labels = []

# %%
type(labels)
# Out:
# list

# %%
for i in range(2014):
    labels.append("fifty")

# %%
labels
# Out:
# ['fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  'fifty',
#  ...]

# %%
len(labels)
# Out:
# 2014

# %%
# Reads an image from a file, decodes it into a dense tensor, and resizes it
# to a fixed shape.
def _parse_function(filename, label):
  image_string = tf.read_file(filename)
  image_decoded = tf.image.decode_jpeg(image_string)
  image_resized = tf.image.resize_images(image_decoded, [28, 28])
  return image_resized, label

# %%
# A vector of filenames.
filenames = tf.constant(onlyfiles)

# %%
# `labels[i]` is the label for the image in `filenames[i].
labels = tf.constant(labels)

# %%
dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
dataset = dataset.map(_parse_function)
